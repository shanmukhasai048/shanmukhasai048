# %% [markdown]
# <a href="https://colab.research.google.com/github/shanmukhasai048/shanmukhasai048/blob/main/214516_python_final_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
s = pd.Series([1,3,5,np. nan,6,8])
print (s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101 ', periods=6)
print (dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,3), index=dates, columns=list('ABD'))
df
# Out:
#                    A         B         D
# 2013-01-01 -2.424221  0.370587  0.524702
# 2013-01-02 -0.618954 -0.389204 -0.876799
# 2013-01-03  1.736860 -1.052187  0.090328
# 2013-01-04  0.972889 -0.492741 -0.277463
# 2013-01-05 -0.240927 -0.270180  0.701109
# 2013-01-06 -0.015207  1.800632  0.273430

# %%
df2 = pd.DataFrame({ ' A ' : 1.,
 ' B  ': pd.Timestamp('  20130102  '),
 ' C  ': pd.Series(1,index=list(range(4))),
 ' D ': np.array([3] * 4),
 ' E  ': pd.Categorical([" test "," train "," test "," train "]),
 ' F  ': ' foo'  })
df2
# Out:
#     A         B     C     D       E     F
# 0  1.0 2013-01-02     1    3    test    foo
# 1  1.0 2013-01-02     1    3   train    foo
# 2  1.0 2013-01-02     1    3    test    foo
# 3  1.0 2013-01-02     1    3   train    foo

# %%
df2.dtypes
# Out:
#  A             float64
#  B      datetime64[ns]
#  C               int64
#  D               int64
#  E            category
#  F              object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.140549  0.699485 -0.602712 -0.158697
# 2013-01-02 -1.037828  1.392488 -0.182219 -0.374984
# 2013-01-03 -1.208725 -0.161731 -0.855585  2.300222
# 2013-01-04  0.577738 -1.074987 -0.092050  0.329327
# 2013-01-05  0.784203  0.515809 -0.609133 -0.476113

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.270806 -0.188948 -0.171507  0.331607
# std    0.876625  1.409660  0.781612  1.026547
# min   -1.208725 -2.504754 -0.855585 -0.476113
# 25%   -0.998565 -0.846673 -0.607528 -0.320912
# 50%   -0.370113  0.177039 -0.392466  0.085315
# 75%    0.468440  0.653566 -0.114592  0.359746
# max    0.784203  1.392488  1.312657  2.300222

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.140549   -1.037828   -1.208725    0.577738    0.784203   -0.880774
# B    0.699485    1.392488   -0.161731   -1.074987    0.515809   -2.504754
# C   -0.602712   -0.182219   -0.855585   -0.092050   -0.609133    1.312657
# D   -0.158697   -0.374984    2.300222    0.329327   -0.476113    0.369886

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.140549  0.699485 -0.602712 -0.158697
# 2013-01-02 -1.037828  1.392488 -0.182219 -0.374984
# 2013-01-03 -1.208725 -0.161731 -0.855585  2.300222
# 2013-01-04  0.577738 -1.074987 -0.092050  0.329327
# 2013-01-05  0.784203  0.515809 -0.609133 -0.476113
# 2013-01-06 -0.880774 -2.504754  1.312657  0.369886

# %%
df.sort_values(by='C')
# Out:
#                    A         B         C         D
# 2013-01-03 -1.208725 -0.161731 -0.855585  2.300222
# 2013-01-05  0.784203  0.515809 -0.609133 -0.476113
# 2013-01-01  0.140549  0.699485 -0.602712 -0.158697
# 2013-01-02 -1.037828  1.392488 -0.182219 -0.374984
# 2013-01-04  0.577738 -1.074987 -0.092050  0.329327
# 2013-01-06 -0.880774 -2.504754  1.312657  0.369886

# %%
df.loc[dates[3]]
# Out:
# A    0.577738
# B   -1.074987
# C   -0.092050
# D    0.329327
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.at[dates[1],'B']
# Out:
# 1.3924880509920758

# %%
df.iloc[3]
# Out:
# A    0.577738
# B   -1.074987
# C   -0.092050
# D    0.329327
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# THE DIFF BW ILOC AND IAT
#  IN ILOC IT GIVES MULTIPLE ROW OUTPUT
# IN IAT IT GIVES SINGLE ROW OUTOUT

# %%
df.iat[1,1]
# Out:
# 1.3924880509920758

# %%
df[df > 0]
#PRINTS THE OUT PUT WHICH IS ABOVE "0"
# Out:
#                    A         B         C         D
# 2013-01-01  1.142313       NaN       NaN       NaN
# 2013-01-02  1.195024  0.271671  1.384719  0.172602
# 2013-01-03       NaN       NaN       NaN  0.884299
# 2013-01-04       NaN  0.156595  0.611558  1.877965
# 2013-01-05       NaN  0.010258  0.153250       NaN
# 2013-01-06       NaN       NaN       NaN  1.538435

# %%
df[df < 0]
#PRINTS THE OUT PUT WHICH IS BELOW "0"
# Out:
#                    A         B         C         D
# 2013-01-01       NaN -0.439408 -1.883156 -2.005374
# 2013-01-02       NaN       NaN       NaN       NaN
# 2013-01-03 -0.852426 -2.029544 -1.679506       NaN
# 2013-01-04 -1.395997       NaN       NaN       NaN
# 2013-01-05 -0.245757       NaN       NaN -0.206170
# 2013-01-06 -1.263474 -0.018567 -1.469508       NaN

# %%
df2 = df.copy()
df2['E'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.683457  0.416853 -1.685036  0.229823    one
# 2013-01-02  0.608165  1.948396 -1.358830  2.274270    one
# 2013-01-03 -0.014217  0.375775  0.389332  0.009646    two
# 2013-01-04  0.666670 -0.204324 -0.190718  1.364718  three
# 2013-01-05  1.528720  0.198817 -0.141956  1.072369   four
# 2013-01-06  0.664123 -0.907822  1.087460  1.148733  three

# %%
df2[df2['E'].isin(['two','four'])]
#printing the particular row based on coloums output
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.014217  0.375775  0.389332  0.009646   two
# 2013-01-05  1.528720  0.198817 -0.141956  1.072369  four

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
print (s1)
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0],'A'] = 0
df.iat[0,1] = 0
df.loc[:,'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.602712  5
# 2013-01-02 -1.037828  1.392488 -0.182219  5
# 2013-01-03 -1.208725 -0.161731 -0.855585  5
# 2013-01-04  0.577738 -1.074987 -0.092050  5
# 2013-01-05  0.784203  0.515809 -0.609133  5
# 2013-01-06 -0.880774 -2.504754  1.312657  5

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.602712 -5
# 2013-01-02 -1.037828 -1.392488 -0.182219 -5
# 2013-01-03 -1.208725 -0.161731 -0.855585 -5
# 2013-01-04 -0.577738 -1.074987 -0.092050 -5
# 2013-01-05 -0.784203 -0.515809 -0.609133 -5
# 2013-01-06 -0.880774 -2.504754 -1.312657 -5

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D    E
# 2013-01-01  0.000000  0.000000 -0.602712  5  1.0
# 2013-01-02 -1.037828  1.392488 -0.182219  5  1.0
# 2013-01-03 -1.208725 -0.161731 -0.855585  5  NaN
# 2013-01-04  0.577738 -1.074987 -0.092050  5  NaN

# %%
 pd.isnull(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.sub(s, axis='index')
# Out:
#                       A   B   C   D
# 2013-01-01 00:00:00 NaN NaN NaN NaN
# 2013-01-02 00:00:00 NaN NaN NaN NaN
# 2013-01-03 00:00:00 NaN NaN NaN NaN
# 2013-01-04 00:00:00 NaN NaN NaN NaN
# 2013-01-05 00:00:00 NaN NaN NaN NaN
# 2013-01-06 00:00:00 NaN NaN NaN NaN
# 0                   NaN NaN NaN NaN
# 1                   NaN NaN NaN NaN
# 2                   NaN NaN NaN NaN
# 3                   NaN NaN NaN NaN
# 4                   NaN NaN NaN NaN
# 5                   NaN NaN NaN NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2013-01-01  0.000000  0.000000 -0.700757   5
# 2013-01-02  1.163460  0.202311 -0.798207  10
# 2013-01-03  0.776228  1.596744 -1.436735  15
# 2013-01-04 -0.023424  0.475692 -1.382176  20
# 2013-01-05  1.108548  0.336473 -1.005655  25
# 2013-01-06  0.343372 -0.900739 -1.981873  30

# %%
df.apply(lambda x: x.max() -x.min())
# Out:
# A    1.992927
# B    3.897242
# C    2.168243
# D    0.000000
# dtype: float64

# %%
 s.value_counts()
# Out:
# 1.0    1
# 3.0    1
# 5.0    1
# 6.0    1
# 8.0    1
# dtype: int64

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  1.592871 -1.300203  0.899148 -1.548683
# 1 -0.731888 -1.849420  0.834753 -0.613530
# 2 -0.951999 -0.707692 -0.633878  0.730623
# 3 -0.474482  1.445827 -0.389677 -0.711178
# 4 -0.540071  1.517042  0.308335 -0.941579
# 5  0.402450  0.450657  1.099794 -0.963043
# 6  1.159634 -1.037432  0.408065  0.543301
# 7  0.503622  0.195643  1.546166  0.720425
# 8  0.003726 -0.071038 -1.253835 -1.215690
# 9 -0.812897 -1.168305 -1.211712 -0.148549

# %%
left = pd.DataFrame({'key': ['foo', ' box'], 'lval': [1, 2]})
right = pd.DataFrame({'key': [' bro', 'foo'], 'rval': [4, 5]})
left
# Out:
#     key  lval
# 0   foo     1
# 1   box     2

# %%
right
# Out:
#     key  rval
# 0   bro     4
# 1   foo     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.525587  0.389894 -0.877125  0.747971
# 1  0.143698 -0.874077  2.498549 -0.356210
# 2 -0.602597 -0.743779 -0.426571  0.490856
# 3  0.810898 -1.851691 -1.525059  0.315148
# 4  0.913507 -0.342748  0.479316 -0.149472
# 5  0.034267  0.742979  2.708986  0.472173
# 6 -0.143055  1.151435  0.856327 -0.676441
# 7  0.260123  0.653587 -0.583587 -0.127692

# %%
df.groupby('B').sum()
#knowing the sum of individuals
# Out:
#                   A         C         D
# B
# -1.851691  0.810898 -1.525059  0.315148
# -0.874077  0.143698  2.498549 -0.356210
# -0.743779 -0.602597 -0.426571  0.490856
# -0.342748  0.913507  0.479316 -0.149472
#  0.389894  0.525587 -0.877125  0.747971
#  0.653587  0.260123 -0.583587 -0.127692
#  0.742979  0.034267  2.708986  0.472173
#  1.151435 -0.143055  0.856327 -0.676441

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[0:8]
df2
#to know the sum of 2 grops completly
# Out:
#                      A         B
# first second
# bar   one    -2.150214 -1.385160
#       two    -1.860823 -1.150279
# baz   one    -1.596059 -1.048591
#       two    -0.247757  0.154789
# foo   one    -1.475726 -0.204826
#       two    -0.513903 -0.380457
# qux   one    -2.263216 -1.925604
#       two    -0.100011  0.057376

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -2.150214
#                B   -1.385160
#        two     A   -1.860823
#                B   -1.150279
# baz    one     A   -1.596059
#                B   -1.048591
#        two     A   -0.247757
#                B    0.154789
# foo    one     A   -1.475726
#                B   -0.204826
#        two     A   -0.513903
#                B   -0.380457
# qux    one     A   -2.263216
#                B   -1.925604
#        two     A   -0.100011
#                B    0.057376
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -2.150214 -1.385160
#       two    -1.860823 -1.150279
# baz   one    -1.596059 -1.048591
#       two    -0.247757  0.154789
# foo   one    -1.475726 -0.204826
#       two    -0.513903 -0.380457
# qux   one    -2.263216 -1.925604
#       two    -0.100011  0.057376

# %% [markdown]
# # ***`SANKALP`***

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C                    -2.051303  -1.627721   0.634866   0.944780   1.122969  \
# A         B
# -1.195703  1.727271   0.447533        NaN        NaN        NaN        NaN
# -0.975770 -0.599556        NaN        NaN        NaN        NaN   0.781805
# -0.895608  0.629076        NaN        NaN        NaN        NaN        NaN
# -0.319613  1.712831        NaN        NaN  -0.166254        NaN        NaN
# -0.054686  0.034182        NaN        NaN        NaN   0.024461        NaN
#  0.000000 -0.136559        NaN  -0.629473        NaN        NaN        NaN
#
# C                     1.837125
# A         B
# -1.195703  1.727271        NaN
# -0.975770 -0.599556        NaN
# -0.895608  0.629076  -0.200115
# -0.319613  1.712831        NaN
# -0.054686  0.034182        NaN
#  0.000000 -0.136559        NaN

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min')
ts
# Out:
# 2012-01-01 00:00:00    136
# 2012-01-01 00:00:01     78
# 2012-01-01 00:00:02    466
# 2012-01-01 00:00:03    101
# 2012-01-01 00:00:04    403
#                       ...
# 2012-01-01 00:01:35    172
# 2012-01-01 00:01:36    297
# 2012-01-01 00:01:37    104
# 2012-01-01 00:01:38    302
# 2012-01-01 00:01:39    175
# Freq: S, Length: 100, dtype: int64

# %%
rng = pd.date_range('1/1/2012', periods=5)
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-01   -0.205277
# 2012-01-02    0.322380
# 2012-01-03   -0.495658
# 2012-01-04    0.441750
# 2012-01-05   -1.350150
# Freq: D, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)

#ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990Q1   -0.426001
# 1990Q2   -0.714325
# 1990Q3    0.384851
# 1990Q4   -0.901568
# 1991Q1    0.628587
# Freq: Q-NOV, dtype: float64

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a','c','c']})
print(df,end="\n")
print("\n")
df.dtypes
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         c
# 5   6         c
# id            int64
# raw_grade    object
# dtype: object

# %%
names = ["harshit" , "sankalp" , "ram", "karthik" , "shanmukha" , "kishen" ]
df.insert(loc = 0 , column = "names" , value = names)
df
# Out:
#    id      names raw_grade
# 0   1    harshit         a
# 1   2    sankalp         b
# 2   3        ram         b
# 3   4    karthik         a
# 4   5  shanmukha         c
# 5   6     kishen         c

# %%
df["grade"] = df["raw_grade"].astype("string")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    c
# 5    c
# Name: grade, dtype: string

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods = 1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.plot()

# %%
df.to_csv("project.csv")

# %%
df.to_excel("project.xlsx" , sheet_name = "project")
